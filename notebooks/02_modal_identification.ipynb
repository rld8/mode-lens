# %% [markdown]
# # Modal identification
# Load a completed run and inspect POD energy, spectra and measured shapes through the same functions used by the app.

# %%
from pathlib import Path
from modelens.adapters.local_repository import LocalExperimentRepository
from modelens.adapters.plotly_presenter import psd_figure, scree_figure

result = LocalExperimentRepository().load(Path('../runs/demo/result.json'))
scree_figure(result).show()
psd_figure(result).show()
